// %%
@file:Repository("https://kotlin.bintray.com/kotlin-datascience")
@file:DependsOn("org.jetbrains.kotlin-deeplearning:api:[0.1.0]")
import org.jetbrains.kotlinx.dl.api.core.*
import org.jetbrains.kotlinx.dl.api.core.layer.*
import org.jetbrains.kotlinx.dl.api.core.layer.twodim.*
import org.jetbrains.kotlinx.dl.api.core.activation.*
import org.jetbrains.kotlinx.dl.api.core.initializer.*
import org.jetbrains.kotlinx.dl.datasets.Dataset
import org.jetbrains.kotlinx.dl.datasets.handlers.*
import org.jetbrains.kotlinx.dl.api.core.loss.Losses
import org.jetbrains.kotlinx.dl.api.core.metric.Metrics
import org.jetbrains.kotlinx.dl.api.core.optimizer.SGD

// %%
val EPOCHS = 2
val TRAINING_BATCH_SIZE = 2000
val TEST_BATCH_SIZE = 1000
val NUM_CHANNELS = 1L
val IMAGE_SIZE = 28L
val SEED = 12L

// %%
val model = Sequential.of(
    Input(IMAGE_SIZE, IMAGE_SIZE, NUM_CHANNELS),
    Conv2D(
        filters = 32,
        kernelSize = longArrayOf(5, 5),
        strides = longArrayOf(1, 1, 1, 1),
        activation = Activations.Relu,
        kernelInitializer = HeNormal(SEED),
        biasInitializer = HeNormal(SEED),
        padding = ConvPadding.SAME
    ),
    MaxPool2D(
        poolSize = intArrayOf(1, 2, 2, 1),
        strides = intArrayOf(1, 2, 2, 1)
    ),
    Conv2D(
        filters = 64,
        kernelSize = longArrayOf(5, 5),
        strides = longArrayOf(1, 1, 1, 1),
        activation = Activations.Relu,
        kernelInitializer = HeNormal(SEED),
        biasInitializer = HeNormal(SEED),
        padding = ConvPadding.SAME
    ),
    MaxPool2D(
        poolSize = intArrayOf(1, 2, 2, 1),
        strides = intArrayOf(1, 2, 2, 1)
    ),
    Flatten(),
    Dense(
        outputSize = 512,
        activation = Activations.Relu,
        kernelInitializer = HeNormal(SEED),
        biasInitializer = Constant(0.1f)
    ),
    Dense(
        outputSize = NUMBER_OF_CLASSES,
        activation = Activations.Linear,
        kernelInitializer = HeNormal(SEED),
        biasInitializer = Constant(0.1f)
    )
)

// %%
val (train, test) = Dataset.createTrainAndTestDatasets(
    TRAIN_IMAGES_ARCHIVE,
    TRAIN_LABELS_ARCHIVE,
    TEST_IMAGES_ARCHIVE,
    TEST_LABELS_ARCHIVE,
    NUMBER_OF_CLASSES,
    ::extractImages,
    ::extractLabels
)

model.use {
    it.compile(
        optimizer = SGD(learningRate = 0.1f),
        loss = Losses.SOFT_MAX_CROSS_ENTROPY_WITH_LOGITS,
        metric = Metrics.ACCURACY
    )

    it.fit(dataset = train, epochs = EPOCHS, batchSize = TRAINING_BATCH_SIZE, verbose = true)

    val accuracy = it.evaluate(dataset = test, batchSize = TEST_BATCH_SIZE).metrics[Metrics.ACCURACY]

    println("Accuracy: $accuracy")
}
// Out:
// Extracting 60000 images of 28x28 from datasets/mnist/train-images-idx3-ubyte.gz
// Extracting 60000 labels from datasets/mnist/train-labels-idx1-ubyte.gz
// Extracting 10000 images of 28x28 from datasets/mnist/t10k-images-idx3-ubyte.gz
// Extracting 10000 labels from datasets/mnist/t10k-labels-idx1-ubyte.gz
// 19:39:33.159 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Conv2D(filters=32, kernelSize=[5, 5], strides=[1, 1, 1, 1], dilations=[1, 1, 1, 1], activation=Relu, kernelInitializer=HeNormal(seed=12) VarianceScaling(scale=2.0, mode=FAN_IN, distribution=TRUNCATED_NORMAL, seed=12), biasInitializer=HeNormal(seed=12) VarianceScaling(scale=2.0, mode=FAN_IN, distribution=TRUNCATED_NORMAL, seed=12), kernelShape=[5, 5, 1, 32], padding=SAME); outputShape: [None, 28, 28, 32]
// 19:39:33.160 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - MaxPool2D(poolSize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding=VALID); outputShape: [None, 14, 14, 32]
// 19:39:33.165 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Conv2D(filters=64, kernelSize=[5, 5], strides=[1, 1, 1, 1], dilations=[1, 1, 1, 1], activation=Relu, kernelInitializer=HeNormal(seed=12) VarianceScaling(scale=2.0, mode=FAN_IN, distribution=TRUNCATED_NORMAL, seed=12), biasInitializer=HeNormal(seed=12) VarianceScaling(scale=2.0, mode=FAN_IN, distribution=TRUNCATED_NORMAL, seed=12), kernelShape=[5, 5, 32, 64], padding=SAME); outputShape: [None, 14, 14, 64]
// 19:39:33.166 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - MaxPool2D(poolSize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding=VALID); outputShape: [None, 7, 7, 64]
// 19:39:33.167 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Flatten; outputShape: [None, 3136]
// 19:39:33.176 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Dense(outputSize=512, activation=Relu, kernelInitializer=HeNormal(seed=12) VarianceScaling(scale=2.0, mode=FAN_IN, distribution=TRUNCATED_NORMAL, seed=12), biasInitializer=Constant(constantValue=0.1), kernelShape=[3136, 512], biasShape=[512]); outputShape: [None, 512]
// 19:39:33.181 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Dense(outputSize=10, activation=Linear, kernelInitializer=HeNormal(seed=12) VarianceScaling(scale=2.0, mode=FAN_IN, distribution=TRUNCATED_NORMAL, seed=12), biasInitializer=Constant(constantValue=0.1), kernelShape=[512, 10], biasShape=[10]); outputShape: [None, 10]
// 19:39:33.319 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Initialization of TensorFlow Graph variables.
// 19:39:34.772 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Initialization of optimizer variables.
// 19:39:39.865 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 3.0657058 metricValue: 0.099 }
// 19:39:42.963 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 95.839905 metricValue: 0.11 }
// 19:39:46.022 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 4.29469107E9 metricValue: 0.089 }
// 19:39:48.830 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 4.3894072E7 metricValue: 0.1015 }
// 19:39:51.671 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 3.5899792 metricValue: 0.1015 }
// 19:39:54.864 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.713005 metricValue: 0.0925 }
// 19:39:57.646 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.5455928 metricValue: 0.0955 }
// 19:40:00.444 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.4115937 metricValue: 0.094 }
// 19:40:03.236 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3697193 metricValue: 0.0925 }
// 19:40:06.248 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3390777 metricValue: 0.0945 }
// 19:40:09.338 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3335896 metricValue: 0.101 }
// 19:40:12.266 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3150022 metricValue: 0.108 }
// 19:40:15.616 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3146017 metricValue: 0.1005 }
// 19:40:18.736 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.312187 metricValue: 0.1015 }
// 19:40:21.723 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3112514 metricValue: 0.0985 }
// 19:40:24.606 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3075068 metricValue: 0.099 }
// 19:40:27.548 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3084447 metricValue: 0.096 }
// 19:40:30.378 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.309462 metricValue: 0.102 }
// 19:40:33.827 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3060234 metricValue: 0.101 }
// 19:40:36.896 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3060381 metricValue: 0.0995 }
// 19:40:39.828 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.306999 metricValue: 0.102 }
// 19:40:42.697 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3034155 metricValue: 0.105 }
// 19:40:45.824 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.305751 metricValue: 0.096 }
// 19:40:49.097 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3043559 metricValue: 0.1065 }
// 19:40:51.982 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3051682 metricValue: 0.103 }
// 19:40:55.053 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3053594 metricValue: 0.0935 }
// 19:40:58.104 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3037329 metricValue: 0.1015 }
// 19:41:01.147 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3042035 metricValue: 0.101 }
// 19:41:04.204 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3023555 metricValue: 0.099 }
// 19:41:06.993 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3029702 metricValue: 0.1 }
// 19:41:06.994 [main] INFO  o.j.kotlinx.dl.api.core.Sequential - epochs: 1 loss: 1.44619504E8 metric: 0.099483326
// 19:41:09.986 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3019292 metricValue: 0.099 }
// 19:41:13.026 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.301829 metricValue: 0.0995 }
// 19:41:16.089 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3029833 metricValue: 0.092 }
// 19:41:19.149 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3026912 metricValue: 0.1175 }
// 19:41:22.103 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3013847 metricValue: 0.1105 }
// 19:41:25.171 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3031068 metricValue: 0.112 }
// 19:41:28.144 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3024056 metricValue: 0.111 }
// 19:41:30.924 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3020067 metricValue: 0.1175 }
// 19:41:33.718 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.2998247 metricValue: 0.1215 }
// 19:41:36.520 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3032556 metricValue: 0.115 }
// 19:41:39.273 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.301235 metricValue: 0.1145 }
// 19:41:42.256 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3019996 metricValue: 0.111 }
// 19:41:45.451 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.2998893 metricValue: 0.1215 }
// 19:41:48.724 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3022103 metricValue: 0.112 }
// 19:41:52.143 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.30281 metricValue: 0.112 }
// 19:41:55.343 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.2998974 metricValue: 0.118 }
// 19:41:58.425 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3011584 metricValue: 0.1185 }
// 19:42:01.488 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3011773 metricValue: 0.1085 }
// 19:42:04.506 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3021197 metricValue: 0.106 }
// 19:42:07.903 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3016684 metricValue: 0.119 }
// 19:42:10.936 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3013375 metricValue: 0.118 }
// 19:42:14.024 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.300793 metricValue: 0.112 }
// 19:42:17.101 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3021295 metricValue: 0.106 }
// 19:42:20.734 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3007288 metricValue: 0.1175 }
// 19:42:23.588 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.302591 metricValue: 0.104 }
// 19:42:26.373 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3030312 metricValue: 0.1025 }
// 19:42:29.325 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3011944 metricValue: 0.1145 }
// 19:42:32.491 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3028657 metricValue: 0.098 }
// 19:42:35.437 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3007755 metricValue: 0.11 }
// 19:42:38.359 [main] DEBUG o.j.kotlinx.dl.api.core.Sequential - Batch stat: { lossValue: 2.3018339 metricValue: 0.107 }
// 19:42:38.359 [main] INFO  o.j.kotlinx.dl.api.core.Sequential - epochs: 2 loss: 2.301762 metric: 0.11086667
// Accuracy: 0.11349999904632568
